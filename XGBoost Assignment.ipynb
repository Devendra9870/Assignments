# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_set = pd.read_csv('D:\\Ineuron\\Data Set\\adult.data', header = None) 
train_set.head(250)
# Out:
#      0                  1       2            3   4                    5   \
# 0    39          State-gov   77516    Bachelors  13        Never-married
# 1    50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 2    38            Private  215646      HS-grad   9             Divorced
# 3    53            Private  234721         11th   7   Married-civ-spouse
# 4    28            Private  338409    Bachelors  13   Married-civ-spouse
# ..   ..                ...     ...          ...  ..                  ...
# 245  56            Private  203580      HS-grad   9   Married-civ-spouse
# 246  58            Private  236596      HS-grad   9   Married-civ-spouse
# 247  32            Private  183916      HS-grad   9        Never-married
# 248  40            Private  207578   Assoc-acdm  12   Married-civ-spouse
# 249  45            Private  153141      HS-grad   9   Married-civ-spouse
#
#                      6               7       8        9     10    11  12  \
# ...

# %%
col_labels = ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
'marital_status', 'occupation','relationship', 'race', 'sex', 'capital_gain',
'capital_loss', 'hours_per_week', 'native_country', 'wage_class']
train_set.columns = col_labels
train_set.head(250)
# Out:
#      age          workclass  fnlwgt    education  education_num  \
# 0     39          State-gov   77516    Bachelors             13
# 1     50   Self-emp-not-inc   83311    Bachelors             13
# 2     38            Private  215646      HS-grad              9
# 3     53            Private  234721         11th              7
# 4     28            Private  338409    Bachelors             13
# ..   ...                ...     ...          ...            ...
# 245   56            Private  203580      HS-grad              9
# 246   58            Private  236596      HS-grad              9
# 247   32            Private  183916      HS-grad              9
# 248   40            Private  207578   Assoc-acdm             12
# 249   45            Private  153141      HS-grad              9
#
#           marital_status          occupation    relationship    race      sex  \
# 0          Never-married        Adm-clerical   Not-in-family   White     Male
# ...

# %%
train_set.info()
train_set.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null object
# fnlwgt            32561 non-null int64
# education         32561 non-null object
# education_num     32561 non-null int64
# marital_status    32561 non-null object
# occupation        32561 non-null object
# relationship      32561 non-null object
# race              32561 non-null object
# sex               32561 non-null object
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null object
# wage_class        32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# (32561, 15)

# %%
train_set.dtypes # to check the data types.
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education_num      int64
# marital_status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital_gain       int64
# capital_loss       int64
# hours_per_week     int64
# native_country    object
# wage_class        object
# dtype: object

# %%
train_set.native_country.value_counts()
# in o/p  ? counts is 583
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
for feature in col_labels:
    if train_set[feature].dtypes ==("object"):
        print('_'*15,feature,end="_")
        print("_"*10)
        print(train_set[feature].value_counts())
# Out:
# _______________ workclass___________
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
# _______________ education___________
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
# _______________ marital_status___________
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
# ...

# %%
for feature in col_labels:
    if train_set[feature].dtypes==("int64"):
        print("_"*10,feature,end="_")
        print("_"*10)
        print(train_set[feature].value_counts())
# Out:
# __________ age___________
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64
# __________ fnlwgt___________
# 164190    13
# 203488    13
# 123011    13
# 113364    12
# 121124    12
#           ..
# 284211     1
# 312881     1
# 177711     1
# 179758     1
# 229376     1
# Name: fnlwgt, Length: 21648, dtype: int64
# __________ education_num___________
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: education_num, dtype: int64
# __________ capital_gain___________
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# ...

# %%
train_set.workclass.replace(' ?', np.nan,inplace=True) # replacing ? value means with np.nan
train_set.workclass.value_counts()
#a.value_counts()
train_set.workclass.isnull().sum()
# Out:
# 1836

# %%
train_set["native_country"].replace(" ?",np.nan,inplace=True)
train_set["native_country"].isnull().sum()
# Out:
# 583

# %%
train_set["occupation"].replace(" ?",np.nan,inplace=True)
train_set["occupation"].isnull().sum()
# Out:
# 1843

# %%
train_set.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# wage_class           0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer(strategy="most_frequent")
train_set['workclass'] = si.fit_transform(train_set[['workclass']])
train_set["native_country"] = si.fit_transform(train_set[["native_country"]])
train_set["occupation"] =si.fit_transform(train_set[['occupation']])

# %%
train_set.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# wage_class        0
# dtype: int64

# %%
# Label Encoding.
from sklearn import preprocessing
pp = preprocessing.LabelEncoder()
train_set["workclass"] = pp.fit_transform(train_set["workclass"])
train_set["workclass"]
# Out:
# 0        6
# 1        5
# 2        3
# 3        3
# 4        3
#         ..
# 32556    3
# 32557    3
# 32558    3
# 32559    3
# 32560    4
# Name: workclass, Length: 32561, dtype: int32

# %%
train_set["education"]=pp.fit_transform(train_set["education"])
train_set["marital_status"] =pp.fit_transform(train_set["marital_status"])
train_set["occupation"] = pp.fit_transform(train_set["occupation"])
train_set["race"] = pp.fit_transform(train_set["race"])
train_set["sex"] = pp.fit_transform(train_set["sex"])
train_set["wage_class"]  = pp.fit_transform(train_set["wage_class"])
train_set["relationship"]=pp.fit_transform(train_set["relationship"])
train_set["native_country"] = pp.fit_transform(train_set["native_country"])

# %%
train_set
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          3  257302          7             12               2
# 32557   40          3  154374         11              9               2
# 32558   58          3  151910         11              9               6
# 32559   22          3  201490         11              9               4
# 32560   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age               32561 non-null int64
# workclass         32561 non-null int32
# fnlwgt            32561 non-null int64
# education         32561 non-null int64
# education_num     32561 non-null int64
# marital_status    32561 non-null int64
# occupation        32561 non-null int64
# relationship      32561 non-null int64
# race              32561 non-null int64
# sex               32561 non-null int64
# capital_gain      32561 non-null int64
# capital_loss      32561 non-null int64
# hours_per_week    32561 non-null int64
# native_country    32561 non-null int32
# wage_class        32561 non-null int64
# dtypes: int32(2), int64(13)
# memory usage: 3.5 MB

# %% [markdown]
# # Test Data

# %%
test_set = pd.read_csv('D:\\Ineuron\\Data Set\\adult.data' , skiprows = 1, header = None) 
col_labels =  ['age', 'workclass', 'fnlwgt', 'education', 'education_num',
'marital_status', 'occupation','relationship', 'race', 'sex', 'capital_gain',
'capital_loss', 'hours_per_week', 'native_country', 'wage_class']
test_set.columns = col_labels
test_set.head(2)
test_set.shape
# Out:
# (32560, 15)

# %%
test_set.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000233D8109508>,
# ...
#       dtype=object)

# %%
# find out the missing values
test_set.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# wage_class        0
# dtype: int64

# %% [markdown]
# # check the Counts of Unique Variable From Each Column.

# %%
for feature in col_labels:
    if test_set[feature].dtypes == ("object"):
        print("_"*10,feature,end="_")
        print("_"*10)
        print(test_set[feature].value_counts())
# Out:
# __________ workclass___________
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
# __________ education___________
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
# __________ marital_status___________
#  Married-civ-spouse       14976
#  Never-married            10682
#  Divorced                  4443
#  Separated                 1025
# ...

# %%
for feature in col_labels:
    if test_set[feature].dtypes=="int64":
        print("_"*12,feature,end="_")
        print("_"*12)
        print(test_set[feature].value_counts())
# Out:
# ____________ age_____________
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 85      3
# 88      3
# 87      1
# 86      1
# Name: age, Length: 73, dtype: int64
# ____________ fnlwgt_____________
# 123011    13
# 203488    13
# 164190    13
# 121124    12
# 148995    12
#           ..
# 68318      1
# 284211     1
# 312881     1
# 177711     1
# 229376     1
# Name: fnlwgt, Length: 21647, dtype: int64
# ____________ education_num_____________
# 9     10501
# 10     7291
# 13     5354
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: education_num, dtype: int64
# ____________ capital_gain_____________
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 4931         1
# 1455         1
# 6097         1
# 22040        1
# 1111         1
# ...

# %%
test_set["workclass"].replace(" ?",np.nan,inplace=True)
test_set["occupation"].replace(" ?",np.nan,inplace=True)
test_set["native_country"].replace(" ?",np.nan,inplace=True)

# %%
test_set.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education_num        0
# marital_status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country     583
# wage_class           0
# dtype: int64

# %%
# filling the missing values
from sklearn.impute import SimpleImputer
si =SimpleImputer(strategy="most_frequent")

for feat in test_set:
    if test_set[feat].dtypes==("object"):
        test_set[feat]=si.fit_transform(test_set[[feat]])

# %%
test_set.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# wage_class        0
# dtype: int64

# %%
for feat1 in test_set:
    if test_set[feat1].dtypes==("object"):
        test_set[feat1]=pp.fit_transform(test_set[feat1])

# %%
test_set
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       50          5   83311          9             13               2
# 1       38          3  215646         11              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          9             13               2
# 4       37          3  284582         12             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %% [markdown]
# # Now we combine train and test data

# %%
combined_data =  pd.concat([train_set,test_set],0)

# %%
combined_data
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
# creation of X and Y variable

x=combined_data.drop(["wage_class"],1)
x
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          6   77516          9             13               4
# 1       50          5   83311          9             13               2
# 2       38          3  215646         11              9               0
# 3       53          3  234721          1              7               2
# 4       28          3  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          7             12               2
# 32556   40          3  154374         11              9               2
# 32557   58          3  151910         11              9               6
# 32558   22          3  201490         11              9               4
# 32559   52          4  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  capital_loss  \
# ...

# %%
y = combined_data["wage_class"]
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: wage_class, Length: 65121, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.75,random_state=150)
x_train.shape ,x_test.shape, y_train.shape , y_test.shape
# Out:
# ((48840, 14), (16281, 14), (48840,), (16281,))

# %%
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

# %%
model= XGBClassifier()
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
accuracy = accuracy_score(y_test,y_pred)
accuracy
# Out:
# 0.8922056384742952

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
      'learning_rate':[1,0.5,0.1,0.01,0.001],
       'max_depth': [3,5,10,20],
       'n_estimators':[10,50,100,200]
}

# %%
grid= GridSearchCV(XGBClassifier(objective='binary:logistic'),param_grid, verbose=3)

# %%
grid.fit(x_train,y_train)
# Out:
# C:\Users\devendra\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.865, total=   0.3s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# [CV]  learning_rate=1, max_depth=3, n_estimators=10, score=0.862, total=   0.3s
# [CV] learning_rate=1, max_depth=3, n_estimators=10 ...................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.5s remaining:    0.0s
# ...

# %%
grid.best_params_
# Out:
# {'learning_rate': 0.1, 'max_depth': 20, 'n_estimators': 200}

# %%
new_model=XGBClassifier(learning_rate= 0.1, max_depth=20, n_estimators= 200)

# %%
new_model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster=None, colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints=None,
#               learning_rate=0.1, max_delta_step=0, max_depth=20,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               n_estimators=200, n_jobs=0, num_parallel_tree=1,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method=None,
#               validate_parameters=False, verbosity=None)

# %%
y_pred1=new_model.predict(x_test)

# %%
accuracy2 =accuracy_score(y_test,y_pred1)

# %%
accuracy2
# Out:
# 0.9604446901295989
